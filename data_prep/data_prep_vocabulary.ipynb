# %%
vocab_book_1 = [
  {
    "en": "evening",
    "de": "Abend"
  },
  {
    "en": "supper",
    "de": "Abendessen"
  },
  {
    "en": "but",
    "de": "aber"
  },
  {
    "en": "(to) refuse",
    "de": "ablehnen"
  },
  {
    "en": "abbreviation",
    "de": "Abkürzung"
  },
  {
    "en": "(to) cancel",
    "de": "absagen"
  },
  {
    "en": "Oh!",
    "de": "Ach!"
  },
  {
    "en": "I see!",
    "de": "Ach so!"
  },
  {
    "en": "(to) pay attention to",
    "de": "achten"
  },
  {
    "en": "aha",
    "de": "aha"
  },
  {
    "en": "idea",
    "de": "Ahnung"
  },
  {
    "en": "accent, stress",
    "de": "Akzent"
  },
  {
    "en": "academic",
    "de": "akademisch"
  },
  {
    "en": "alcohol-free",
    "de": "alkoholfrei"
  },
  {
    "en": "every, all",
    "de": "alle"
  },
  {
    "en": "general medicine",
    "de": "Allgemeinmedizin"
  },
  {
    "en": "alphabet",
    "de": "Alphabet"
  },
  {
    "en": "also, then",
    "de": "also"
  },
  {
    "en": "old",
    "de": "alt"
  },
  {
    "en": "flat/apartment in an older building",
    "de": "Altbauwohnung"
  },
  {
    "en": "at the",
    "de": "am"
  },
  {
    "en": "on, in",
    "de": "an"
  },
  {
    "en": "at the beginning",
    "de": "Anfang"
  },
  {
    "en": "(to) start",
    "de": "anfangen"
  },
  {
    "en": "(to) specify, (to) give",
    "de": "angeben"
  },
  {
    "en": "(to) mark (with an X)",
    "de": "ankreuzen"
  },
  {
    "en": "call",
    "de": "Anruf"
  },
  {
    "en": "telephone answering machine",
    "de": "Anrufbeantworter"
  },
  {
    "en": "(to) write (sth.) down",
    "de": "anschreiben"
  },
  {
    "en": "(to) look at",
    "de": "ansehen"
  },
  {
    "en": "answer, reply",
    "de": "Antwort"
  },
  {
    "en": "(to) answer, (to) reply",
    "de": "antworten"
  },
  {
    "en": "work",
    "de": "Arbeit"
  },
  {
    "en": "(to) work",
    "de": "arbeiten"
  },
  {
    "en": "directions (in a course book)",
    "de": "Arbeitsanweisung"
  },
  {
    "en": "work room, study",
    "de": "Arbeitszimmer"
  },
  {
    "en": "poor wretch",
    "de": "Arme"
  },
  {
    "en": "(medical) doctor",
    "de": "Arzt"
  },
  {
    "en": "task, assignment",
    "de": "Aufgabe"
  },
  {
    "en": "(to) get up",
    "de": "aufstehen"
  },
  {
    "en": "Good-bye!",
    "de": "Auf Wiedersehen!"
  },
  {
    "en": "(directory) information",
    "de": "Auskunft"
  },
  {
    "en": "foreign countries, abroad",
    "de": "Ausland"
  },
  {
    "en": "Second-language German Education",
    "de": "Auslandsgermanistik"
  },
  {
    "en": "excuse",
    "de": "Ausrede"
  },
  {
    "en": "(to) choose, (to) pick",
    "de": "auswählen"
  },
  {
    "en": "car, automobile",
    "de": "Auto"
  },
  {
    "en": "(German) freeway, expressway",
    "de": "Autobahn"
  },
  {
    "en": "license plate; car number plate",
    "de": "Autoschild"
  },
  {
    "en": "bath(room)",
    "de": "Bad"
  },
  {
    "en": "(to) have a bath",
    "de": "baden"
  },
  {
    "en": "bathtub",
    "de": "Badewanne"
  },
  {
    "en": "bathroom",
    "de": "Badezimmer"
  },
  {
    "en": "train, railway",
    "de": "Bahn"
  },
  {
    "en": "station",
    "de": "Bahnhof"
  },
  {
    "en": "balcony",
    "de": "Balkon"
  },
  {
    "en": "bank",
    "de": "Bank"
  },
  {
    "en": "bar",
    "de": "Bar"
  },
  {
    "en": "base, ground",
    "de": "Basis"
  },
  {
    "en": "farmhouse",
    "de": "Bauernhaus"
  },
  {
    "en": "(to) build, (to) form",
    "de": "bauen"
  },
  {
    "en": "Bavarian",
    "de": "bayrisch"
  },
  {
    "en": "(to) answer",
    "de": "beantworten"
  },
  {
    "en": "by, near, close to, at, for",
    "de": "bei"
  },
  {
    "en": "both (of them)",
    "de": "beide"
  },
  {
    "en": "acquaintance",
    "de": "Bekannte"
  },
  {
    "en": "(to) receive, (to) get",
    "de": "bekommen"
  },
  {
    "en": "(to) name",
    "de": "benennen"
  },
  {
    "en": "report (inferred from verb 'berichten')",
    "de": "Bericht"
  },
  {
    "en": "(to) report, (to) make a report",
    "de": "berichten"
  },
  {
    "en": "occupation, profession",
    "de": "Beruf"
  },
  {
    "en": "(e)special(ly)",
    "de": "besonders"
  },
  {
    "en": "(to) order",
    "de": "bestellen"
  },
  {
    "en": "certain, specific",
    "de": "bestimmte"
  },
  {
    "en": "(to) stress",
    "de": "betonen"
  },
  {
    "en": "stressed",
    "de": "betont"
  },
  {
    "en": "bed",
    "de": "Bett"
  },
  {
    "en": "(to) pay",
    "de": "bezahlen"
  },
  {
    "en": "library",
    "de": "Bibliothek"
  },
  {
    "en": "picture",
    "de": "Bild"
  },
  {
    "en": "(to) form",
    "de": "bilden"
  },
  {
    "en": "inexpensive, cheap",
    "de": "billig"
  },
  {
    "en": "bilingual",
    "de": "bilingual"
  },
  {
    "en": "bingo",
    "de": "Bingo"
  },
  {
    "en": "am (to be)",
    "de": "bin"
  },
  {
    "en": "biography",
    "de": "Biografie"
  },
  {
    "en": "biology",
    "de": "Biologie"
  },
  {
    "en": "up to, until, to",
    "de": "bis"
  },
  {
    "en": "see you tomorrow",
    "de": "bis morgen"
  },
  {
    "en": "till then!",
    "de": "Bis dann!"
  },
  {
    "en": "request",
    "de": "Bitte"
  },
  {
    "en": "please",
    "de": "bitte"
  },
  {
    "en": "(to) ask (for)",
    "de": "bitten"
  },
  {
    "en": "pencil (inferred from context)",
    "de": "Bleistift"
  },
  {
    "en": "wide",
    "de": "breit"
  },
  {
    "en": "Translation not found in provided sources.",
    "de": "Brief"
  },
  {
    "en": "book",
    "de": "Buch"
  },
  {
    "en": "letter (of the alphabet)",
    "de": "Buchstabe"
  },
  {
    "en": "(to) spell",
    "de": "buchstabieren"
  },
  {
    "en": "(to) need",
    "de": "brauchen"
  },
  {
    "en": "bookshelf",
    "de": "Bücherregal"
  },
  {
    "en": "office",
    "de": "Büro"
  },
  {
    "en": "office chair",
    "de": "Bürostuhl"
  },
  {
    "en": "café",
    "de": "Café"
  },
  {
    "en": "cafeteria",
    "de": "Cafeteria"
  },
  {
    "en": "cappuccino",
    "de": "Cappuccino"
  },
  {
    "en": "CD",
    "de": "CD"
  },
  {
    "en": "CD player",
    "de": "CD-Player"
  },
  {
    "en": "chaotic",
    "de": "chaotisch"
  },
  {
    "en": "chemistry",
    "de": "Chemie"
  },
  {
    "en": "Chinese",
    "de": "Chinesisch"
  },
  {
    "en": "cola",
    "de": "Cola"
  },
  {
    "en": "collage",
    "de": "Collage"
  },
  {
    "en": "computer",
    "de": "Computer"
  },
  {
    "en": "Danish",
    "de": "Dänisch"
  },
  {
    "en": "beside that, beside it",
    "de": "daneben"
  },
  {
    "en": "thank you",
    "de": "danke"
  },
  {
    "en": "This/that is ...",
    "de": "Das ist"
  },
  {
    "en": "That comes to ...",
    "de": "Das macht"
  },
  {
    "en": "These/these are ...",
    "de": "Das sind"
  },
  {
    "en": "(to) think",
    "de": "denken"
  },
  {
    "en": "then",
    "de": "denn"
  },
  {
    "en": "German",
    "de": "Deutsche"
  },
  {
    "en": "German teacher",
    "de": "Deutschlehrer/in"
  },
  {
    "en": "dialogue",
    "de": "Dialog"
  },
  {
    "en": "dialogue graphic",
    "de": "Dialoggrafik"
  },
  {
    "en": "the",
    "de": "die"
  },
  {
    "en": "Tuesday",
    "de": "Dienstag"
  },
  {
    "en": "thing",
    "de": "Ding"
  },
  {
    "en": "disco",
    "de": "Disko"
  },
  {
    "en": "still, after all",
    "de": "doch"
  },
  {
    "en": "documentation",
    "de": "Dokumentation"
  },
  {
    "en": "there",
    "de": "dort"
  },
  {
    "en": "Thursday",
    "de": "Donnerstag"
  },
  {
    "en": "(to be one's) turn, (to be) up",
    "de": "dran"
  },
  {
    "en": "(to) stay outside",
    "de": "draußenbleiben"
  },
  {
    "en": "you (one person, informal)",
    "de": "du"
  },
  {
    "en": "dark",
    "de": "dunkel"
  },
  {
    "en": "(to) cross out, (to) strike through",
    "de": "durchstreichen"
  },
  {
    "en": "dynamic(s)",
    "de": "Dynamik"
  },
  {
    "en": "echo",
    "de": "Echo"
  },
  {
    "en": "email",
    "de": "E-Mail"
  },
  {
    "en": "simple, simply",
    "de": "einfach"
  },
  {
    "en": "a",
    "de": "ein"
  },
  {
    "en": "resident, inhabitant",
    "de": "Einwohner/in"
  },
  {
    "en": "family home",
    "de": "Einfamilienhaus"
  },
  {
    "en": "(to) go shopping (for), (to) buy",
    "de": "einkaufen"
  },
  {
    "en": "a bit",
    "de": "ein bisschen"
  },
  {
    "en": "ice, ice-cream",
    "de": "Eis"
  },
  {
    "en": "iced tea",
    "de": "Eistee"
  },
  {
    "en": "electronics engineer",
    "de": "Elektronikingenieur/in"
  },
  {
    "en": "end",
    "de": "Ende"
  },
  {
    "en": "English",
    "de": "Englisch"
  },
  {
    "en": "ensemble",
    "de": "Ensemble"
  },
  {
    "en": "Excuse me!",
    "de": "Entschuldigung!"
  },
  {
    "en": "he",
    "de": "er"
  },
  {
    "en": "(to) complete, (to) fill in",
    "de": "ergänzen"
  },
  {
    "en": "result",
    "de": "Ergebnis"
  },
  {
    "en": "(to) explain",
    "de": "erklären"
  },
  {
    "en": "only, not before",
    "de": "erst"
  },
  {
    "en": "it",
    "de": "es"
  },
  {
    "en": "espresso",
    "de": "Espresso"
  },
  {
    "en": "(to) eat",
    "de": "essen"
  },
  {
    "en": "dining table",
    "de": "Esstisch"
  },
  {
    "en": "something",
    "de": "etwas"
  },
  {
    "en": "Europe",
    "de": "Europa"
  },
  {
    "en": "European",
    "de": "Europäer/in"
  },
  {
    "en": "export",
    "de": "Export"
  },
  {
    "en": "(to) drive, (to) go (by bus, train, etc.)",
    "de": "fahren"
  },
  {
    "en": "(train/bus etc.) schedule",
    "de": "Fahrplan"
  },
  {
    "en": "bicycle",
    "de": "Fahrrad"
  },
  {
    "en": "family",
    "de": "Familie"
  },
  {
    "en": "family name",
    "de": "Familienname"
  },
  {
    "en": "fantastic",
    "de": "fantastisch"
  },
  {
    "en": "Fanta (a soft drink)",
    "de": "Fanta"
  },
  {
    "en": "almost",
    "de": "fast"
  },
  {
    "en": "favourite",
    "de": "Favorit"
  },
  {
    "en": "mistake",
    "de": "Fehler"
  },
  {
    "en": "holidays, vacation",
    "de": "Ferien"
  },
  {
    "en": "television",
    "de": "Fernseher"
  },
  {
    "en": "ready, finished",
    "de": "fertig"
  },
  {
    "en": "permanent",
    "de": "fest"
  },
  {
    "en": "fire department",
    "de": "Feuerwehr"
  },
  {
    "en": "film",
    "de": "Film"
  },
  {
    "en": "(to) find",
    "de": "finden"
  },
  {
    "en": "Finnish",
    "de": "Finnisch"
  },
  {
    "en": "firm, company",
    "de": "Firma"
  },
  {
    "en": "flair",
    "de": "Flair"
  },
  {
    "en": "Flemish",
    "de": "Flämisch"
  },
  {
    "en": "(to) fly",
    "de": "fliegen"
  },
  {
    "en": "hall(way), corridor",
    "de": "Flur"
  },
  {
    "en": "formal",
    "de": "formal"
  },
  {
    "en": "form",
    "de": "Form"
  },
  {
    "en": "photograph",
    "de": "Foto"
  },
  {
    "en": "question",
    "de": "Frage"
  },
  {
    "en": "(to) ask a question",
    "de": "fragen"
  },
  {
    "en": "French",
    "de": "Französisch"
  },
  {
    "en": "woman, Mrs.",
    "de": "Frau"
  },
  {
    "en": "free",
    "de": "frei"
  },
  {
    "en": "Friday",
    "de": "Freitag"
  },
  {
    "en": "foreign",
    "de": "fremd"
  },
  {
    "en": "friend, girlfriend, boyfriend",
    "de": "Freund/in"
  },
  {
    "en": "breakfast",
    "de": "Frühstück"
  },
  {
    "en": "(to) have breakfast",
    "de": "frühstücken"
  },
  {
    "en": "fountain pen",
    "de": "Füller"
  },
  {
    "en": "foot",
    "de": "Fuß"
  },
  {
    "en": "football; soccer",
    "de": "Fußball"
  },
  {
    "en": "(to) function, (to) work",
    "de": "funktionieren"
  },
  {
    "en": "for",
    "de": "für"
  },
  {
    "en": "not ... at all",
    "de": "gar kein"
  },
  {
    "en": "garden, yard",
    "de": "Garten"
  },
  {
    "en": "object",
    "de": "Gegenstand"
  },
  {
    "en": "opposite",
    "de": "Gegenteil"
  },
  {
    "en": "(to) go",
    "de": "gehen"
  },
  {
    "en": "(to) belong (to)",
    "de": "gehören"
  },
  {
    "en": "together, in common",
    "de": "gemeinsam"
  },
  {
    "en": "exactly, precisely",
    "de": "genau!"
  },
  {
    "en": "precisely as, exactly as",
    "de": "genauso"
  },
  {
    "en": "open (inferred from context)",
    "de": "geöffnet"
  },
  {
    "en": "geography",
    "de": "Geografie"
  },
  {
    "en": "geographic",
    "de": "geografisch"
  },
  {
    "en": "gladly, (to) like to",
    "de": "gern"
  },
  {
    "en": "yesterday",
    "de": "gestern"
  },
  {
    "en": "beverage, drink",
    "de": "Getränk"
  },
  {
    "en": "separately",
    "de": "getrennt"
  },
  {
    "en": "winner",
    "de": "Gewinner/in"
  },
  {
    "en": "guitar",
    "de": "Gitarre"
  },
  {
    "en": "the same",
    "de": "gleich"
  },
  {
    "en": "global",
    "de": "global"
  },
  {
    "en": "luck",
    "de": "Glück"
  },
  {
    "en": "graphic",
    "de": "Grafik"
  },
  {
    "en": "border",
    "de": "Grenze"
  },
  {
    "en": "Greek",
    "de": "Griechisch"
  },
  {
    "en": "big",
    "de": "groß"
  },
  {
    "en": "group",
    "de": "Gruppe"
  },
  {
    "en": "root word",
    "de": "Grundwort"
  },
  {
    "en": "greeting",
    "de": "Gruß"
  },
  {
    "en": "Hello!",
    "de": "Grüß dich!"
  },
  {
    "en": "Hello! Good day!",
    "de": "Guten Tag!"
  },
  {
    "en": "higher secondary school, high school",
    "de": "Gymnasium"
  },
  {
    "en": "(to) have",
    "de": "haben"
  },
  {
    "en": "port, harbour",
    "de": "Hafen"
  },
  {
    "en": "half (of the next hour)",
    "de": "halb"
  },
  {
    "en": "Hello!, Hi!",
    "de": "Hallo!"
  },
  {
    "en": "hand (as in to shake hands)",
    "de": "Hand"
  },
  {
    "en": "cell(ular) phone",
    "de": "Handy"
  },
  {
    "en": "ugly",
    "de": "Hässlich"
  },
  {
    "en": "house, building",
    "de": "Haus"
  },
  {
    "en": "homework",
    "de": "Hausaufgabe"
  },
  {
    "en": "(to) call, (to) be named",
    "de": "heißen"
  },
  {
    "en": "notebook",
    "de": "Heft"
  },
  {
    "en": "native land",
    "de": "Heimat"
  },
  {
    "en": "bright",
    "de": "hell"
  },
  {
    "en": "(to) help",
    "de": "helfen"
  },
  {
    "en": "cooker, stove",
    "de": "Herd"
  },
  {
    "en": "Mr.",
    "de": "Herr"
  },
  {
    "en": "origins, where one comes from",
    "de": "Herkunft"
  },
  {
    "en": "here",
    "de": "hier"
  },
  {
    "en": "help",
    "de": "Hilfe"
  },
  {
    "en": "hobby",
    "de": "Hobby"
  },
  {
    "en": "high-rise, skyscraper",
    "de": "Hochhaus"
  },
  {
    "en": "(to) hear, (to) listen to",
    "de": "hören"
  },
  {
    "en": "radio play",
    "de": "Hörspiel"
  },
  {
    "en": "today",
    "de": "heute"
  },
  {
    "en": "dog",
    "de": "Hund"
  },
  {
    "en": "I",
    "de": "ich"
  },
  {
    "en": "text in the first person (about oneself)",
    "de": "Ich-Text"
  },
  {
    "en": "your (formal address)",
    "de": "Ihr"
  },
  {
    "en": "always",
    "de": "immer"
  },
  {
    "en": "in the",
    "de": "im"
  },
  {
    "en": "import",
    "de": "Import"
  },
  {
    "en": "in",
    "de": "in"
  },
  {
    "en": "industry",
    "de": "Industrie"
  },
  {
    "en": "interesting",
    "de": "interessant"
  },
  {
    "en": "international",
    "de": "international"
  },
  {
    "en": "internet",
    "de": "Internet"
  },
  {
    "en": "Italian",
    "de": "Italienisch"
  },
  {
    "en": "year",
    "de": "Jahr"
  },
  {
    "en": "Japanese",
    "de": "Japaner/in"
  },
  {
    "en": "each, every",
    "de": "jeden"
  },
  {
    "en": "now",
    "de": "jetzt"
  },
  {
    "en": "job",
    "de": "Job"
  },
  {
    "en": "boy",
    "de": "Junge"
  },
  {
    "en": "coffee",
    "de": "Kaffee"
  },
  {
    "en": "broken, not working",
    "de": "kaputt"
  },
  {
    "en": "Karaoke",
    "de": "Karaoke"
  },
  {
    "en": "map",
    "de": "Karte"
  },
  {
    "en": "box",
    "de": "Kasten"
  },
  {
    "en": "no, not any, not a",
    "de": "kein"
  },
  {
    "en": "(to) know",
    "de": "kennen"
  },
  {
    "en": "(to) meet (sb. for the first time)",
    "de": "kennenlernen"
  },
  {
    "en": "children's room, nursery",
    "de": "Kinderzimmer"
  },
  {
    "en": "cinema, movies",
    "de": "Kino"
  },
  {
    "en": "visit to the cinema",
    "de": "Kinobesuch"
  },
  {
    "en": "yes, of course",
    "de": "klar!"
  },
  {
    "en": "small, little",
    "de": "klein"
  },
  {
    "en": "duel between cooks",
    "de": "Kochduell"
  },
  {
    "en": "(to) cook",
    "de": "kochen"
  },
  {
    "en": "suitcase",
    "de": "Koffer"
  },
  {
    "en": "(to) come",
    "de": "kommen"
  },
  {
    "en": "commode, chest of drawers",
    "de": "Kommode"
  },
  {
    "en": "communication(s)",
    "de": "Kommunikation"
  },
  {
    "en": "(to) comment on",
    "de": "kommentieren"
  },
  {
    "en": "can, could",
    "de": "können"
  },
  {
    "en": "concert",
    "de": "Konzert"
  },
  {
    "en": "cooperation",
    "de": "Kooperation"
  },
  {
    "en": "cooperate",
    "de": "kooperieren"
  },
  {
    "en": "head",
    "de": "Kopf"
  },
  {
    "en": "(to) cost",
    "de": "kosten"
  },
  {
    "en": "health insurance company",
    "de": "Krankenkasse"
  },
  {
    "en": "chalk",
    "de": "Kreide"
  },
  {
    "en": "kitchen",
    "de": "Küche"
  },
  {
    "en": "kitchen cupboard",
    "de": "Küchenschrank"
  },
  {
    "en": "kitchen table",
    "de": "Küchentisch"
  },
  {
    "en": "refrigerator",
    "de": "Kühlschrank"
  },
  {
    "en": "(ball-point) pen",
    "de": "Kuli"
  },
  {
    "en": "culture",
    "de": "Kultur"
  },
  {
    "en": "cultural",
    "de": "kulturell"
  },
  {
    "en": "short",
    "de": "kurz"
  },
  {
    "en": "shortly / a bit after",
    "de": "kurz nach"
  },
  {
    "en": "shortly / a bit before",
    "de": "kurz vor"
  },
  {
    "en": "course, class",
    "de": "Kurs"
  },
  {
    "en": "course leader, teacher",
    "de": "Kursleiter/in"
  },
  {
    "en": "classroom",
    "de": "Kursraum"
  },
  {
    "en": "course participant",
    "de": "Kursteilnehmer/in"
  },
  {
    "en": "(to) kiss",
    "de": "küssen"
  },
  {
    "en": "site, situation, location",
    "de": "Lage"
  },
  {
    "en": "lamp",
    "de": "Lampe"
  },
  {
    "en": "map",
    "de": "Landkarte"
  },
  {
    "en": "long",
    "de": "lang"
  },
  {
    "en": "slow(ly)",
    "de": "langsam"
  },
  {
    "en": "making noise",
    "de": "Lärm"
  },
  {
    "en": "aloud, out loud",
    "de": "laut"
  },
  {
    "en": "(to) live",
    "de": "leben"
  },
  {
    "en": "teacher",
    "de": "Lehrer/in"
  },
  {
    "en": "textbook",
    "de": "Lehrbuch"
  },
  {
    "en": "sorrow (part of idiom 'Tut mir Leid')",
    "de": "Leid"
  },
  {
    "en": "soft, quiet",
    "de": "leise"
  },
  {
    "en": "learn",
    "de": "lernen"
  },
  {
    "en": "learning card file",
    "de": "Lernkartei"
  },
  {
    "en": "learning poster",
    "de": "Lernplakat"
  },
  {
    "en": "(to) read",
    "de": "lesen"
  },
  {
    "en": "Luxembourgish",
    "de": "Letzeburgisch"
  },
  {
    "en": "people",
    "de": "Leute"
  },
  {
    "en": "(to) love",
    "de": "lieben"
  },
  {
    "en": "(to) lie, is",
    "de": "liegen"
  },
  {
    "en": "(to the / on the) left",
    "de": "links"
  },
  {
    "en": "list",
    "de": "Liste"
  },
  {
    "en": "lion",
    "de": "Löwe"
  },
  {
    "en": "solution",
    "de": "Lösung"
  },
  {
    "en": "lottery numbers",
    "de": "Lottozahlen"
  },
  {
    "en": "lyrical",
    "de": "lyrisch"
  },
  {
    "en": "(to) make, (to) do",
    "de": "machen"
  },
  {
    "en": "girl",
    "de": "Mädchen"
  },
  {
    "en": "one, a person, you (impersonal)",
    "de": "man"
  },
  {
    "en": "sometimes",
    "de": "manchmal"
  },
  {
    "en": "man",
    "de": "Mann"
  },
  {
    "en": "(to) mark",
    "de": "Markieren"
  },
  {
    "en": "marketplace",
    "de": "Marktplatz"
  },
  {
    "en": "material",
    "de": "Material"
  },
  {
    "en": "medical technology",
    "de": "Medizintechnologie"
  },
  {
    "en": "than",
    "de": "mehr"
  },
  {
    "en": "multilingualism",
    "de": "Mehrsprachigkeit"
  },
  {
    "en": "my",
    "de": "mein"
  },
  {
    "en": "mostly, usually",
    "de": "meistens"
  },
  {
    "en": "melody",
    "de": "Melodie"
  },
  {
    "en": "person, people",
    "de": "Mensch"
  },
  {
    "en": "rent (inferred from context)",
    "de": "Miete"
  },
  {
    "en": "café latte",
    "de": "Milchkaffee"
  },
  {
    "en": "million",
    "de": "Million"
  },
  {
    "en": "city of over a million people",
    "de": "Millionenstadt"
  },
  {
    "en": "small metropolitan city",
    "de": "Minimetropole"
  },
  {
    "en": "minute",
    "de": "Minute"
  },
  {
    "en": "with",
    "de": "mit"
  },
  {
    "en": "(to) come with/along",
    "de": "mitkommen"
  },
  {
    "en": "(to) read along",
    "de": "mitlesen"
  },
  {
    "en": "(to) take part, (to) participate",
    "de": "mitmachen"
  },
  {
    "en": "noon",
    "de": "Mittag"
  },
  {
    "en": "lunch",
    "de": "Mittagessen"
  },
  {
    "en": "lunch break",
    "de": "Mittagspause"
  },
  {
    "en": "Wednesday",
    "de": "Mittwoch"
  },
  {
    "en": "midnight",
    "de": "Mitternacht"
  },
  {
    "en": "modern",
    "de": "modern"
  },
  {
    "en": "would like",
    "de": "möchten"
  },
  {
    "en": "furniture",
    "de": "Möbel"
  },
  {
    "en": "piece of furniture",
    "de": "Möbelstück"
  },
  {
    "en": "(to) like",
    "de": "mögen"
  },
  {
    "en": "possibility",
    "de": "Möglichkeit"
  },
  {
    "en": "moment",
    "de": "Moment"
  },
  {
    "en": "Monday",
    "de": "Montag"
  },
  {
    "en": "tomorrow",
    "de": "morgen"
  },
  {
    "en": "in the morning",
    "de": "morgens"
  },
  {
    "en": "music",
    "de": "Musik"
  },
  {
    "en": "musician",
    "de": "Musiker/in"
  },
  {
    "en": "must, (to) have to",
    "de": "müssen"
  },
  {
    "en": "mother tongue",
    "de": "Muttersprache"
  },
  {
    "en": "coin",
    "de": "Münze"
  },
  {
    "en": "to",
    "de": "nach"
  },
  {
    "en": "neighbour",
    "de": "Nachbar"
  },
  {
    "en": "neighbouring country",
    "de": "Nachbarland"
  },
  {
    "en": "neighbouring region",
    "de": "Nachbarregion"
  },
  {
    "en": "afternoon",
    "de": "Nachmittag"
  },
  {
    "en": "(to) ask about (sth.), (to) ask questions",
    "de": "nachfragen"
  },
  {
    "en": "repeat (what you hear)",
    "de": "nachsprechen"
  },
  {
    "en": "at night",
    "de": "nachts"
  },
  {
    "en": "name",
    "de": "Name"
  },
  {
    "en": "national",
    "de": "national"
  },
  {
    "en": "no",
    "de": "nein"
  },
  {
    "en": "(to) take, (to) have",
    "de": "nehmen"
  },
  {
    "en": "(to) name, (to) give",
    "de": "nennen"
  },
  {
    "en": "new",
    "de": "neu"
  },
  {
    "en": "neutral",
    "de": "neutral"
  },
  {
    "en": "not",
    "de": "nicht"
  },
  {
    "en": "Dutch",
    "de": "Niederländisch"
  },
  {
    "en": "note(s)",
    "de": "Notiz"
  },
  {
    "en": "(to) take notes, (to) note down",
    "de": "notieren"
  },
  {
    "en": "North",
    "de": "Norden"
  },
  {
    "en": "normal",
    "de": "normal"
  },
  {
    "en": "north of",
    "de": "nördlich"
  },
  {
    "en": "zero; nought (midnight)",
    "de": "null"
  },
  {
    "en": "only",
    "de": "nur"
  },
  {
    "en": "upstairs",
    "de": "oben"
  },
  {
    "en": "or",
    "de": "oder"
  },
  {
    "en": "official",
    "de": "offiziell"
  },
  {
    "en": "often",
    "de": "oft"
  },
  {
    "en": "Okay!",
    "de": "Okay!"
  },
  {
    "en": "opera",
    "de": "Oper"
  },
  {
    "en": "orange",
    "de": "Orange"
  },
  {
    "en": "orange juice",
    "de": "Orangensaft"
  },
  {
    "en": "orchestra",
    "de": "Orchester"
  },
  {
    "en": "(to) put in order",
    "de": "ordnen"
  },
  {
    "en": "orientation, orienteering",
    "de": "Orientierung"
  },
  {
    "en": "place",
    "de": "Ort"
  },
  {
    "en": "East",
    "de": "Osten"
  },
  {
    "en": "overhead projector",
    "de": "Overheadprojektor"
  },
  {
    "en": "(to) pack",
    "de": "packen"
  },
  {
    "en": "pair",
    "de": "Paar"
  },
  {
    "en": "breakdown",
    "de": "Panne"
  },
  {
    "en": "paper",
    "de": "Papier"
  },
  {
    "en": "park",
    "de": "Park"
  },
  {
    "en": "partner",
    "de": "Partner/in"
  },
  {
    "en": "interviewing a partner",
    "de": "Partnerinterview"
  },
  {
    "en": "party",
    "de": "Party"
  },
  {
    "en": "(to) fit, (to) match",
    "de": "passen"
  },
  {
    "en": "(to) happen, (to) go on",
    "de": "passieren"
  },
  {
    "en": "break",
    "de": "Pause"
  },
  {
    "en": "person",
    "de": "Person"
  },
  {
    "en": "information about a person",
    "de": "Personenangabe"
  },
  {
    "en": "guessing people (twenty questions)",
    "de": "Personenraten"
  },
  {
    "en": "pilot",
    "de": "Pilot/in"
  },
  {
    "en": "room, place",
    "de": "Platz"
  },
  {
    "en": "plan",
    "de": "Plan"
  },
  {
    "en": "police",
    "de": "Polizei"
  },
  {
    "en": "Polish",
    "de": "Polnisch"
  },
  {
    "en": "popular",
    "de": "populär"
  },
  {
    "en": "position",
    "de": "Position"
  },
  {
    "en": "postcard",
    "de": "Postkarte"
  },
  {
    "en": "postal code, zip code",
    "de": "Postleitzahl"
  },
  {
    "en": "practice",
    "de": "Praxis"
  },
  {
    "en": "price",
    "de": "Preis"
  },
  {
    "en": "percent",
    "de": "Prozent"
  },
  {
    "en": "project",
    "de": "Projekt"
  },
  {
    "en": "per",
    "de": "pro"
  },
  {
    "en": "Portuguese",
    "de": "Portugiesisch"
  },
  {
    "en": "punctuality",
    "de": "Pünktlichkeit"
  },
  {
    "en": "punctual, on time",
    "de": "pünktlich"
  },
  {
    "en": "square metre",
    "de": "qm"
  },
  {
    "en": "square meter",
    "de": "Quadratmeter"
  },
  {
    "en": "quiz",
    "de": "Quiz"
  },
  {
    "en": "radio",
    "de": "Radio"
  },
  {
    "en": "radio broadcast, program",
    "de": "Radioprogramm"
  },
  {
    "en": "rap",
    "de": "Rap"
  },
  {
    "en": "(to) guess",
    "de": "raten"
  },
  {
    "en": "city/town hall",
    "de": "Rathaus"
  },
  {
    "en": "cheque, bill, invoice",
    "de": "Rechnung"
  },
  {
    "en": "(to the / on the) right",
    "de": "rechts"
  },
  {
    "en": "expression",
    "de": "Redemittel"
  },
  {
    "en": "expression box",
    "de": "Redemittelkasten"
  },
  {
    "en": "shelves",
    "de": "Regal"
  },
  {
    "en": "region",
    "de": "Region"
  },
  {
    "en": "regional",
    "de": "regional"
  },
  {
    "en": "rule",
    "de": "Regel"
  },
  {
    "en": "series, order",
    "de": "Reihenfolge"
  },
  {
    "en": "practical/technical secondary school",
    "de": "Realschule"
  },
  {
    "en": "restaurant",
    "de": "Restaurant"
  },
  {
    "en": "correct, right",
    "de": "richtig"
  },
  {
    "en": "role play",
    "de": "Rollenspiel"
  },
  {
    "en": "back",
    "de": "Rücken"
  },
  {
    "en": "back pains, backache",
    "de": "Rückenschmerzen"
  },
  {
    "en": "quiet, peaceful",
    "de": "ruhig"
  },
  {
    "en": "Russian",
    "de": "Russisch"
  },
  {
    "en": "thing",
    "de": "Sache"
  },
  {
    "en": "(to) say",
    "de": "sagen"
  },
  {
    "en": "(to) collect, (to) gather",
    "de": "Sammeln"
  },
  {
    "en": "Saturday",
    "de": "Samstag"
  },
  {
    "en": "sentence",
    "de": "Satz"
  },
  {
    "en": "yes-no question",
    "de": "Satzfrage"
  },
  {
    "en": "shadow",
    "de": "Schatten"
  },
  {
    "en": "bowl",
    "de": "Schale"
  },
  {
    "en": "bill, note",
    "de": "Schein"
  },
  {
    "en": "bedroom",
    "de": "Schlafzimmer"
  },
  {
    "en": "(to) sleep",
    "de": "schlafen"
  },
  {
    "en": "(to) go to sleep (inferred from context)",
    "de": "schlafen gehen"
  },
  {
    "en": "cupboard, wardrobe",
    "de": "Schrank"
  },
  {
    "en": "desk",
    "de": "Schreibtisch"
  },
  {
    "en": "desk lamp",
    "de": "Schreibtischlampe"
  },
  {
    "en": "(to) write",
    "de": "schreiben"
  },
  {
    "en": "school",
    "de": "Schule"
  },
  {
    "en": "student",
    "de": "Schüler/in"
  },
  {
    "en": "already, here: have you ever been...",
    "de": "schon"
  },
  {
    "en": "sponge, chalk eraser",
    "de": "Schwamm"
  },
  {
    "en": "(to) swim",
    "de": "schwimmen"
  },
  {
    "en": "heavy",
    "de": "schwer"
  },
  {
    "en": "Swedish",
    "de": "Schwedisch"
  },
  {
    "en": "sight worth seeing",
    "de": "Sehenswürdigkeit"
  },
  {
    "en": "(to) see, (to) look at",
    "de": "sehen"
  },
  {
    "en": "page",
    "de": "Seite"
  },
  {
    "en": "(to) be",
    "de": "sein"
  },
  {
    "en": "since; for",
    "de": "seit"
  },
  {
    "en": "self-evaluation (inferred from section title)",
    "de": "Selbstevaluation"
  },
  {
    "en": "seminar",
    "de": "Seminar"
  },
  {
    "en": "semester",
    "de": "Semester"
  },
  {
    "en": "armchair",
    "de": "Sessel"
  },
  {
    "en": "oneself",
    "de": "sich"
  },
  {
    "en": "you (formal address)",
    "de": "Sie"
  },
  {
    "en": "syllable",
    "de": "Silbe"
  },
  {
    "en": "skater paradise",
    "de": "Skaterparadies"
  },
  {
    "en": "skiing",
    "de": "Skifahren"
  },
  {
    "en": "skyline",
    "de": "Skyline"
  },
  {
    "en": "Slovakian",
    "de": "Slowakisch"
  },
  {
    "en": "in this/that way",
    "de": "so"
  },
  {
    "en": "sofa",
    "de": "Sofa"
  },
  {
    "en": "summer",
    "de": "Sommer"
  },
  {
    "en": "Sunday",
    "de": "Sonntag"
  },
  {
    "en": "(to) sort",
    "de": "sortieren"
  },
  {
    "en": "sociology",
    "de": "Soziologie"
  },
  {
    "en": "fun (inferred from context)",
    "de": "Spaß"
  },
  {
    "en": "late",
    "de": "spät"
  },
  {
    "en": "Spanish",
    "de": "Spanisch"
  },
  {
    "en": "specialty",
    "de": "Spezialität"
  },
  {
    "en": "consultation hours",
    "de": "Sprechzeit"
  },
  {
    "en": "(to) speak",
    "de": "sprechen"
  },
  {
    "en": "speaker, person speaking",
    "de": "Sprecher"
  },
  {
    "en": "language",
    "de": "Sprache"
  },
  {
    "en": "language institute/school",
    "de": "Sprachinstitut"
  },
  {
    "en": "speech shadow",
    "de": "Sprachschatten"
  },
  {
    "en": "language school",
    "de": "Sprachschule"
  },
  {
    "en": "sport(s)",
    "de": "Sport"
  },
  {
    "en": "sportstudio",
    "de": "Sportstudio"
  },
  {
    "en": "mirror",
    "de": "Spiegel"
  },
  {
    "en": "game",
    "de": "Spiel"
  },
  {
    "en": "(to) play",
    "de": "spielen"
  },
  {
    "en": "playground",
    "de": "Spielplatz"
  },
  {
    "en": "start",
    "de": "Start"
  },
  {
    "en": "dictation of names of cities",
    "de": "Städtediktat"
  },
  {
    "en": "guessing cities",
    "de": "Städteraten"
  },
  {
    "en": "city",
    "de": "Stadt"
  },
  {
    "en": "city map",
    "de": "Stadtplan"
  },
  {
    "en": "station",
    "de": "Station"
  },
  {
    "en": "traffic jam",
    "de": "Stau"
  },
  {
    "en": "(to) stand, (to) be situated",
    "de": "stehen"
  },
  {
    "en": "floor lamp",
    "de": "Stehlampe"
  },
  {
    "en": "(to) put, (to) ask a question",
    "de": "stellen"
  },
  {
    "en": "storey, floor",
    "de": "Stock"
  },
  {
    "en": "Stop!",
    "de": "Stopp!"
  },
  {
    "en": "student",
    "de": "Student/in"
  },
  {
    "en": "student residence",
    "de": "Studentenwohnheim"
  },
  {
    "en": "chair",
    "de": "Stuhl"
  },
  {
    "en": "hour",
    "de": "Stunde"
  },
  {
    "en": "(to) study",
    "de": "studieren"
  },
  {
    "en": "(to) search, (to) look for",
    "de": "suchen"
  },
  {
    "en": "South",
    "de": "Süden"
  },
  {
    "en": "south of",
    "de": "südlich"
  },
  {
    "en": "supermarket",
    "de": "Supermarkt"
  },
  {
    "en": "symbol",
    "de": "Symbol"
  },
  {
    "en": "systematic(ally)",
    "de": "systematisch"
  },
  {
    "en": "table (with columns and rows)",
    "de": "Tabelle"
  },
  {
    "en": "chalkboard, blackboard",
    "de": "Tafel"
  },
  {
    "en": "day",
    "de": "Tag"
  },
  {
    "en": "Hi! (short form of Guten Tag!)",
    "de": "Tag!"
  },
  {
    "en": "agenda, schedule",
    "de": "Tagesablauf"
  },
  {
    "en": "talk show",
    "de": "Talkshow"
  },
  {
    "en": "bag",
    "de": "Tasche"
  },
  {
    "en": "cup",
    "de": "Tasse"
  },
  {
    "en": "taxi depot",
    "de": "Taxizentrale"
  },
  {
    "en": "tea",
    "de": "Tee"
  },
  {
    "en": "technique, technology",
    "de": "Technik"
  },
  {
    "en": "part",
    "de": "Teil"
  },
  {
    "en": "telecommunication(s)",
    "de": "Telekommunikation"
  },
  {
    "en": "telephone",
    "de": "Telefon"
  },
  {
    "en": "telephone book",
    "de": "Telefonbuch"
  },
  {
    "en": "telephone number",
    "de": "Telefonnummer"
  },
  {
    "en": "(to) talk on the phone",
    "de": "telefonieren"
  },
  {
    "en": "temperature",
    "de": "Temperatur"
  },
  {
    "en": "tennis ball",
    "de": "Tennisball"
  },
  {
    "en": "appointment",
    "de": "Termin"
  },
  {
    "en": "expensive",
    "de": "teuer"
  },
  {
    "en": "text",
    "de": "Text"
  },
  {
    "en": "theatre",
    "de": "Theater"
  },
  {
    "en": "theme, topic",
    "de": "Thema"
  },
  {
    "en": "table",
    "de": "Tisch"
  },
  {
    "en": "toilet",
    "de": "Toilette"
  },
  {
    "en": "sound",
    "de": "Ton"
  },
  {
    "en": "tourist",
    "de": "Tourist"
  },
  {
    "en": "tradition",
    "de": "Tradition"
  },
  {
    "en": "(to) train",
    "de": "trainieren"
  },
  {
    "en": "transport(ation)",
    "de": "Transport"
  },
  {
    "en": "dream",
    "de": "Traum"
  },
  {
    "en": "dream flat/apartment",
    "de": "Traumwohnung"
  },
  {
    "en": "(to) carry",
    "de": "tragen"
  },
  {
    "en": "meeting, get-together",
    "de": "Treffen"
  },
  {
    "en": "(to) meet, (to) get together",
    "de": "treffen"
  },
  {
    "en": "stairway, stairwell",
    "de": "Treppenhaus"
  },
  {
    "en": "(to) drink",
    "de": "trinken"
  },
  {
    "en": "bye-bye",
    "de": "Tschüss!"
  },
  {
    "en": "Czech",
    "de": "Tschechisch"
  },
  {
    "en": "tower",
    "de": "Turm"
  },
  {
    "en": "door",
    "de": "Tür"
  },
  {
    "en": "Sorry",
    "de": "Tut mir Leid"
  },
  {
    "en": "TV = television",
    "de": "TV"
  },
  {
    "en": "Turkish",
    "de": "Türkisch"
  },
  {
    "en": "(to) practice, (to) drill",
    "de": "üben"
  },
  {
    "en": "over, more than",
    "de": "über"
  },
  {
    "en": "bank (of a river, canal, etc.)",
    "de": "Ufer"
  },
  {
    "en": "o'clock, watch",
    "de": "Uhr"
  },
  {
    "en": "time of day",
    "de": "Uhrzeit"
  },
  {
    "en": "umlaut, mutated vowel",
    "de": "Umlaut"
  },
  {
    "en": "moving",
    "de": "Umzug"
  },
  {
    "en": "moving chaos",
    "de": "Umzugschaos"
  },
  {
    "en": "moving box",
    "de": "Umzugskarton"
  },
  {
    "en": "(to) move",
    "de": "umziehen"
  },
  {
    "en": "and",
    "de": "und"
  },
  {
    "en": "unpunctual (inferred from context)",
    "de": "unpünktlich"
  },
  {
    "en": "our",
    "de": "unser"
  },
  {
    "en": "lessons",
    "de": "Unterricht"
  },
  {
    "en": "difference",
    "de": "Unterschied"
  },
  {
    "en": "(to) underline",
    "de": "unterstreichen"
  },
  {
    "en": "university",
    "de": "Universität"
  },
  {
    "en": "vase",
    "de": "Vase"
  },
  {
    "en": "date, meeting",
    "de": "Verabredung"
  },
  {
    "en": "(to) agree to (a meeting/date)",
    "de": "verabreden"
  },
  {
    "en": "leave-taking, saying good-bye",
    "de": "Verabschiedung"
  },
  {
    "en": "(to be) forbidden",
    "de": "verbieten"
  },
  {
    "en": "(to) connect",
    "de": "verbinden"
  },
  {
    "en": "verb ending",
    "de": "Verbendung"
  },
  {
    "en": "(to) forget",
    "de": "vergessen"
  },
  {
    "en": "(to) compare",
    "de": "vergleichen"
  },
  {
    "en": "married (to)",
    "de": "verheiratet"
  },
  {
    "en": "traffic, transportation",
    "de": "Verkehr"
  },
  {
    "en": "different",
    "de": "verschiedene"
  },
  {
    "en": "(to) understand",
    "de": "verstehen"
  },
  {
    "en": "delay",
    "de": "Verspätung"
  },
  {
    "en": "(to) use",
    "de": "verwenden"
  },
  {
    "en": "video",
    "de": "Video"
  },
  {
    "en": "video recorder",
    "de": "Videorekorder"
  },
  {
    "en": "video station (inferred from section title)",
    "de": "Videostation"
  },
  {
    "en": "a lot of, much, many",
    "de": "viel"
  },
  {
    "en": "many, much, a lot of",
    "de": "viele"
  },
  {
    "en": "quarter past",
    "de": "viertel nach"
  },
  {
    "en": "quarter to",
    "de": "viertel vor"
  },
  {
    "en": "violin",
    "de": "Violine"
  },
  {
    "en": "visa",
    "de": "Visum"
  },
  {
    "en": "full",
    "de": "voll"
  },
  {
    "en": "from, of (possessive)",
    "de": "von"
  },
  {
    "en": "(to) prepare",
    "de": "vorbereiten"
  },
  {
    "en": "before that",
    "de": "vorher"
  },
  {
    "en": "first name",
    "de": "Vorname"
  },
  {
    "en": "(to) suggest",
    "de": "vorschlagen"
  },
  {
    "en": "(to) introduce (oneself)",
    "de": "vorstellen"
  },
  {
    "en": "question using a question word",
    "de": "W-Frage"
  },
  {
    "en": "currency",
    "de": "Währung"
  },
  {
    "en": "when",
    "de": "wann"
  },
  {
    "en": "warm",
    "de": "warm"
  },
  {
    "en": "what",
    "de": "was"
  },
  {
    "en": "bathroom sink, washbasin",
    "de": "Waschbecken"
  },
  {
    "en": "washer, washing machine",
    "de": "Waschmaschine"
  },
  {
    "en": "water",
    "de": "Wasser"
  },
  {
    "en": "(to) wait",
    "de": "warten"
  },
  {
    "en": "alarm",
    "de": "Wecker"
  },
  {
    "en": "(to) change",
    "de": "wechseln"
  },
  {
    "en": "wine",
    "de": "Wein"
  },
  {
    "en": "which",
    "de": "welcher"
  },
  {
    "en": "known world-wide",
    "de": "weltbekannt"
  },
  {
    "en": "who",
    "de": "wer"
  },
  {
    "en": "West",
    "de": "Westen"
  },
  {
    "en": "important",
    "de": "wichtig"
  },
  {
    "en": "(to) repeat",
    "de": "wiederholen"
  },
  {
    "en": "how",
    "de": "wie"
  },
  {
    "en": "Pardon?",
    "de": "Wie bitte?"
  },
  {
    "en": "How late is it? What time is it?",
    "de": "Wie spät ist es?"
  },
  {
    "en": "winter sport(s)",
    "de": "Wintersport"
  },
  {
    "en": "really (inferred from context)",
    "de": "wirklich"
  },
  {
    "en": "(to) know (inferred from context)",
    "de": "wissen"
  },
  {
    "en": "where",
    "de": "wo"
  },
  {
    "en": "week",
    "de": "Woche"
  },
  {
    "en": "day of the week",
    "de": "Wochentag"
  },
  {
    "en": "from where",
    "de": "woher"
  },
  {
    "en": "(to) live",
    "de": "wohnen"
  },
  {
    "en": "lifestyle, way of living",
    "de": "Wohnform"
  },
  {
    "en": "apartment, flat",
    "de": "Wohnung"
  },
  {
    "en": "living room",
    "de": "Wohnzimmer"
  },
  {
    "en": "word",
    "de": "Wort"
  },
  {
    "en": "stressed syllable in a word",
    "de": "Wortakzent"
  },
  {
    "en": "word card (inferred from context)",
    "de": "Wortkarte"
  },
  {
    "en": "word network",
    "de": "Wortnetz"
  },
  {
    "en": "vocabulary (inferred from section title)",
    "de": "Wortschatz"
  },
  {
    "en": "dictionary",
    "de": "Wörterbuch"
  },
  {
    "en": "word list",
    "de": "Wörterliste"
  },
  {
    "en": "about what",
    "de": "worüber"
  },
  {
    "en": "number",
    "de": "Zahl"
  },
  {
    "en": "(to) pay",
    "de": "zahlen"
  },
  {
    "en": "(number) lottery",
    "de": "Zahlenlotto"
  },
  {
    "en": "dentist",
    "de": "Zahnarzt"
  },
  {
    "en": "(to) count",
    "de": "zählen"
  },
  {
    "en": "drawing",
    "de": "Zeichnung"
  },
  {
    "en": "time",
    "de": "Zeit"
  },
  {
    "en": "date, time, information about time",
    "de": "Zeitangabe"
  },
  {
    "en": "schedule",
    "de": "Zeitplan"
  },
  {
    "en": "newspaper",
    "de": "Zeitung"
  },
  {
    "en": "central",
    "de": "zentral"
  },
  {
    "en": "note, slip of paper",
    "de": "Zettel"
  },
  {
    "en": "(to) show",
    "de": "zeigen"
  },
  {
    "en": "quite",
    "de": "ziemlich"
  },
  {
    "en": "room",
    "de": "Zimmer"
  },
  {
    "en": "circus",
    "de": "Zirkus"
  },
  {
    "en": "to, too",
    "de": "zu"
  },
  {
    "en": "in pairs",
    "de": "zu zweit"
  },
  {
    "en": "(to) match",
    "de": "zuordnen"
  },
  {
    "en": "train",
    "de": "Zug"
  },
  {
    "en": "first",
    "de": "zuerst"
  },
  {
    "en": "at home",
    "de": "zuhause"
  },
  {
    "en": "(to) agree",
    "de": "Zustimmen"
  },
  {
    "en": "together",
    "de": "zusammen"
  },
  {
    "en": "(to) belong together",
    "de": "zusammengehören"
  },
  {
    "en": "back",
    "de": "zurück"
  },
  {
    "en": "(to) come back (inferred from context)",
    "de": "zurückkommen"
  },
  {
    "en": "between",
    "de": "zwischen"
  },
  {
    "en": "two times, twice",
    "de": "zweimal"
  }
]

# %%
en_list = [i['en'] for i in vocab_book_1]
de_list = [i['de'] for i in vocab_book_1]

# %%
import random

# %% [markdown]
# En to multiple De

# %%
def get_questions():
    example = random.choice(vocab_book_1)
    en_example = example['en']
    de_example = example['de']

    de_options = []

    i = 0

    while i <4:
        de_option = random.choice(de_list)
        if de_option != de_example:
            de_options.append(de_option)
            i += 1

    de_options.append(de_example)

    return {
        "english": en_example,
        "options": de_options,
        "correct_option":de_example
    }

# %%
vocab_1_4 = [get_questions() for _ in range(1000)]

# %%
import json

# %%
with open('/Users/anilbattalahalli/coding/python_stuff/mint_lang/saurkraut/maatukalike/data_prepvocab_1_4.json', 'w') as f:
    json.dump(vocab_1_4, f)
